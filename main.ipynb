# %%
import yfinance as yf
import pandas as pd

# %%
amzn = yf.Ticker("AMZN")

# %%
# Get stock information
amzn.info
# Out:
# {'address1': '410 Terry Avenue North',
#  'city': 'Seattle',
#  'state': 'WA',
#  'zip': '98109-5210',
#  'country': 'United States',
#  'phone': '206 266 1000',
#  'website': 'https://www.aboutamazon.com',
#  'industry': 'Internet Retail',
#  'industryDisp': 'Internet Retail',
#  'sector': 'Consumer Cyclical',
#  'longBusinessSummary': "Amazon.com, Inc. engages in the retail sale of consumer products and subscriptions through online and physical stores in North America and internationally. It operates through three segments: North America, International, and Amazon Web Services (AWS). The company's products offered through its stores include merchandise and content purchased for resale; and products offered by third-party sellers. It also manufactures and sells electronic devices, including Kindle, Fire tablets, Fire TVs, Rings, Blink, eero, and Echo; and develops and produces media content. In addition, the company offers programs that enable sellers to sell their products in its stores; and programs that allow authors, musicians, filmmakers, Twitch streamers, skill and app developers, and others to publish and sell content. Further, it provides compute, storage, database, analytics, machine learning, and other services, as well as fulfillment, advertising, and digital content subscriptions. Additionally, the company offers Amazon Prime, a membership program. It serves consumers, sellers, developers, enterprises, content creators, and advertisers. The company was incorporated in 1994 and is headquartered in Seattle, Washington.",
#  'fullTimeEmployees': 1541000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Jeffrey P. Bezos',
#    'age': 58,
#    'title': 'Founder & Exec. Chairman',
#    'yearBorn': 1964,
#    'fiscalYear': 2022,
#    'totalPay': 1681840,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Andrew R. Jassy',
#    'age': 54,
#    'title': 'Pres, CEO & Director',
#    'yearBorn': 1968,
#    'fiscalYear': 2022,
#    'totalPay': 1298723,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Brian T. Olsavsky',
#    'age': 58,
#    'title': 'Sr. VP & CFO',
#    'yearBorn': 1964,
#    'fiscalYear': 2022,
#    'totalPay': 319850,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. David A. Zapolsky',
#    'age': 58,
#    'title': 'Sr. VP of Global Public Policy & Gen. Counsel',
#    'yearBorn': 1964,
#    'fiscalYear': 2022,
#    'totalPay': 319850,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Douglas J. Herrington',
#    'age': 55,
#    'title': 'Chief Exec. Officer of Worldwide Amazon Stores',
#    'yearBorn': 1967,
#    'fiscalYear': 2022,
#    'totalPay': 335438,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Adam N. Selipsky',
#    'age': 55,
#    'title': 'Chief Exec. Officer of Amazon Web Services, Inc.',
#    'yearBorn': 1967,
#    'fiscalYear': 2022,
#    'totalPay': 360613,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Shelley L. Reynolds',
#    'age': 57,
#    'title': 'VP, Worldwide Controller & Principal Accounting Officer',
#    'yearBorn': 1965,
#    'fiscalYear': 2009,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Werner  Vogels',
#    'title': 'Chief Technology Officer',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Dave  Fildes',
#    'title': 'Director of Investor Relations',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Anuradha  Aggarwal',
#    'title': 'CMO & Director of User Growth',
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 5,
#  'boardRisk': 10,
#  'compensationRisk': 10,
#  'shareHolderRightsRisk': 2,
#  'overallRisk': 10,
#  'governanceEpochDate': 1688169600,
#  'compensationAsOfEpochDate': 1672444800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 128.25,
#  'open': 129.69,
#  'dayLow': 129.33,
#  'dayHigh': 133.01,
#  'regularMarketPreviousClose': 128.25,
#  'regularMarketOpen': 129.69,
#  'regularMarketDayLow': 129.33,
#  'regularMarketDayHigh': 133.01,
#  'payoutRatio': 0.0,
#  'beta': 1.257855,
#  'trailingPE': 314.78574,
#  'forwardPE': 51.24419,
#  'volume': 45962738,
#  'regularMarketVolume': 45962738,
#  'averageVolume': 59553403,
#  'averageVolume10days': 58861920,
#  'averageDailyVolume10Day': 58861920,
#  'bid': 0.0,
#  'ask': 0.0,
#  'bidSize': 1100,
#  'askSize': 800,
#  'marketCap': 1356527566848,
#  'fiftyTwoWeekLow': 81.43,
#  'fiftyTwoWeekHigh': 146.57,
#  'priceToSalesTrailing12Months': 2.5843692,
#  'fiftyDayAverage': 126.2134,
#  'twoHundredDayAverage': 105.3488,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'USD',
#  'enterpriseValue': 1470663360512,
#  'profitMargins': 0.00818,
#  'floatShares': 8985094328,
#  'sharesOutstanding': 10260400128,
#  'sharesShort': 78540027,
#  'sharesShortPriorMonth': 81213619,
#  'sharesShortPreviousMonthDate': 1686787200,
#  'dateShortInterest': 1689292800,
#  'sharesPercentSharesOut': 0.0077,
#  'heldPercentInsiders': 0.09718,
#  'heldPercentInstitutions': 0.60534,
#  'shortRatio': 1.43,
#  'shortPercentOfFloat': 0.0101,
#  'impliedSharesOutstanding': 0,
#  'bookValue': 15.064,
#  'priceToBook': 8.776554,
#  'lastFiscalYearEnd': 1672444800,
#  'nextFiscalYearEnd': 1703980800,
#  'mostRecentQuarter': 1680220800,
#  'netIncomeToCommon': 4294000128,
#  'trailingEps': 0.42,
#  'forwardEps': 2.58,
#  'pegRatio': 1.11,
#  'lastSplitFactor': '20:1',
#  'lastSplitDate': 1654473600,
#  'enterpriseToRevenue': 2.802,
#  'enterpriseToEbitda': 25.714,
#  '52WeekChange': -2.3487687,
#  'SandP52WeekChange': 11.25617,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'AMZN',
#  'underlyingSymbol': 'AMZN',
#  'shortName': 'Amazon.com, Inc.',
#  'longName': 'Amazon.com, Inc.',
#  'firstTradeDateEpochUtc': 863703000,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': '261fd26b-0151-3813-b0d0-97e4ed4c6505',
#  'messageBoardId': 'finmb_18749',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 132.21,
#  'targetHighPrice': 180.0,
#  'targetLowPrice': 99.0,
#  'targetMeanPrice': 143.17,
#  'targetMedianPrice': 145.0,
#  'recommendationMean': 1.8,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 46,
#  'totalCash': 64405000192,
#  'totalCashPerShare': 6.277,
#  'ebitda': 57194000384,
#  'totalDebt': 178546999296,
#  'quickRatio': 0.689,
#  'currentRatio': 0.923,
#  'totalRevenue': 524896993280,
#  'debtToEquity': 115.545,
#  'revenuePerShare': 51.416,
#  'returnOnAssets': 0.01906,
#  'returnOnEquity': 0.029760001,
#  'grossProfits': 225152000000,
#  'freeCashflow': 9030625280,
#  'operatingCashflow': 54329999360,
#  'revenueGrowth': 0.094,
#  'grossMargins': 0.44728002,
#  'ebitdaMargins': 0.10896,
#  'operatingMargins': 0.02542,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 5.1645}

# %%
# Get the historical market data
hist = amzn.history(period="max")
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1997-05-15 00:00:00-04:00    0.121875    0.125000    0.096354    0.097917
# 1997-05-16 00:00:00-04:00    0.098438    0.098958    0.085417    0.086458
# 1997-05-19 00:00:00-04:00    0.088021    0.088542    0.081250    0.085417
# 1997-05-20 00:00:00-04:00    0.086458    0.087500    0.081771    0.081771
# 1997-05-21 00:00:00-04:00    0.081771    0.082292    0.068750    0.071354
# ...                               ...         ...         ...         ...
# 2023-07-24 00:00:00-04:00  130.309998  131.660004  128.350006  128.800003
# 2023-07-25 00:00:00-04:00  129.309998  129.580002  128.529999  129.130005
# 2023-07-26 00:00:00-04:00  126.510002  129.080002  126.110001  128.149994
# 2023-07-27 00:00:00-04:00  131.000000  132.630005  127.790001  128.250000
# 2023-07-28 00:00:00-04:00  129.690002  133.009995  129.330002  132.210007
#
#                                Volume  Dividends  Stock Splits
# Date
# 1997-05-15 00:00:00-04:00  1443120000        0.0           0.0
# 1997-05-16 00:00:00-04:00   294000000        0.0           0.0
# 1997-05-19 00:00:00-04:00   122136000        0.0           0.0
# 1997-05-20 00:00:00-04:00   109344000        0.0           0.0
# 1997-05-21 00:00:00-04:00   377064000        0.0           0.0
# ...                               ...        ...           ...
# 2023-07-24 00:00:00-04:00    45591100        0.0           0.0
# 2023-07-25 00:00:00-04:00    39236700        0.0           0.0
# 2023-07-26 00:00:00-04:00    53910100        0.0           0.0
# 2023-07-27 00:00:00-04:00    52610700        0.0           0.0
# 2023-07-28 00:00:00-04:00    46234700        0.0           0.0
#
# [6594 rows x 7 columns]

# %%
amzn.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2024-04-25 16:00:00-04:00           NaN           NaN          NaN
# 2024-01-31 05:00:00-05:00           NaN           NaN          NaN
# 2023-10-25 06:00:00-04:00           NaN           NaN          NaN
# 2023-08-03 17:00:00-04:00          0.35           NaN          NaN
# 2023-08-03 16:00:00-04:00          0.35           NaN          NaN
# 2023-04-27 12:00:00-04:00          0.21          0.31       0.4636
# 2023-02-02 11:00:00-05:00          0.18          0.25       0.4256
# 2022-10-27 12:00:00-04:00          0.22          0.17      -0.2108
# 2022-07-28 12:00:00-04:00          0.14          0.18       0.2490
# 2022-04-28 12:00:00-04:00          0.42          0.37      -0.1170
# 2022-02-03 11:00:00-05:00          0.18          0.29       0.6248
# 2021-10-28 12:00:00-04:00          0.45          0.31      -0.3139

# %%
hist.plot(kind="line", figsize=(12,12), subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)
